# %%
import plotly.express as px
from data import make_global_df

df = make_global_df()

fig = px.line(df, x="date", y=["confirmed", "deaths", "recovered"], 
              template="plotly_dark",labels={
    "value":"Cases",
    "variable":"Condition",
    "date":"Date"
},
hover_data={
    "variable":False,
    "value":':,'
}
             )
fig.update_xaxes(rangeslider_visible=True)
fig["data"][0]["line"]["color"] = "#e74c3c"
fig["data"][1]["line"]["color"] = "#8e44ad" 
fig["data"][2]["line"]["color"] = "#27ae60"
fig
# Out:
# <div>                            <div id="4a22f907-e2f6-42e0-a340-0e1dea66686f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a22f907-e2f6-42e0-a340-0e1dea66686f")) {                    Plotly.newPlot(                        "4a22f907-e2f6-42e0-a340-0e1dea66686f",                        [{"customdata": [["confirmed", 555], ["confirmed", 654], ["confirmed", 941], ["confirmed", 1434], ["confirmed", 2118], ["confirmed", 2927], ["confirmed", 5578], ["confirmed", 6167], ["confirmed", 8235], ["confirmed", 9927], ["confirmed", 12038], ["confirmed", 16787], ["confirmed", 19887], ["confirmed", 23898], ["confirmed", 27643], ["confirmed", 30803], ["confirmed", 34396], ["confirmed", 37130], ["confirmed", 40160], ["confirmed", 42769], ["confirmed", 44811], ["confirmed", 45229], ["confirmed", 60382], ["confirmed", 66909], ["confirmed", 69051], ["confirmed", 71235], ["confirmed", 73270], ["confirmed", 75152], ["confirmed", 75652], ["confirmed", 76212], ["confirmed", 76841], ["confirmed", 78602], ["confirmed", 78982], ["confirmed", 79546], ["confirmed", 80399], ["confirmed", 81376], ["confirmed", 82736], ["confirmed", 84121], ["confirmed", 86014], ["confirmed", 88397], ["confirmed", 90375], ["confirmed", 92959], ["confirmed", 95276], ["confirmed", 98040], ["confirmed", 102040], ["confirmed", 106102], ["confirmed", 110062], ["confirmed", 114025], ["confirmed", 119036], ["confirmed", 126717], ["confirmed", 132506], ["confirmed", 146887], ["confirmed", 157965], ["confirmed", 169258], ["confirmed", 184002], ["confirmed", 199932], ["confirmed", 219462], ["confirmed", 246618], ["confirmed", 277253], ["confirmed", 309223], ["confirmed", 343456], ["confirmed", 386823], ["confirmed", 428295], ["confirmed", 479279], ["confirmed", 542006], ["confirmed", 606988], ["confirmed", 674380], ["confirmed", 733777], ["confirmed", 799018], ["confirmed", 875842], ["confirmed", 952368], ["confirmed", 1033702], ["confirmed", 1116958], ["confirmed", 1197315], ["confirmed", 1269291], ["confirmed", 1342524], ["confirmed", 1420265], ["confirmed", 1504296], ["confirmed", 1590776], ["confirmed", 1678316], ["confirmed", 1754531], ["confirmed", 1849884], ["confirmed", 1920029], ["confirmed", 1991375], ["confirmed", 2073248], ["confirmed", 2170168], ["confirmed", 2257981], ["confirmed", 2331375], ["confirmed", 2411347], ["confirmed", 2485850], ["confirmed", 2561729], ["confirmed", 2639748], ["confirmed", 2727991], ["confirmed", 2812178], ["confirmed", 2895859], ["confirmed", 2968049], ["confirmed", 3037754], ["confirmed", 3113246], ["confirmed", 3190735], ["confirmed", 3274139], ["confirmed", 3361356], ["confirmed", 3441576], ["confirmed", 3518135], ["confirmed", 3595235], ["confirmed", 3675767], ["confirmed", 3765725], ["confirmed", 3854800], ["confirmed", 3946080], ["confirmed", 4031014], ["confirmed", 4106229], ["confirmed", 4183146], ["confirmed", 4267441], ["confirmed", 4352288], ["confirmed", 4449054], ["confirmed", 4545482], ["confirmed", 4639704], ["confirmed", 4717128], ["confirmed", 4805859], ["confirmed", 4903092], ["confirmed", 5005903], ["confirmed", 5112508], ["confirmed", 5218600], ["confirmed", 5323287], ["confirmed", 5417853], ["confirmed", 5504248], ["confirmed", 5597560], ["confirmed", 5700620], ["confirmed", 5820202], ["confirmed", 5941244], ["confirmed", 6078261], ["confirmed", 6184917], ["confirmed", 6280511], ["confirmed", 6401952], ["confirmed", 6520126], ["confirmed", 6647409], ["confirmed", 6778310], ["confirmed", 6913202], ["confirmed", 7025172], ["confirmed", 7127703], ["confirmed", 7252461], ["confirmed", 7387034], ["confirmed", 7525216], ["confirmed", 7653814], ["confirmed", 7789270], ["confirmed", 7922027], ["confirmed", 8041844], ["confirmed", 8183744], ["confirmed", 8326301], ["confirmed", 8466697], ["con ...
